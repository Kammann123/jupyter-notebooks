# %%
# Ejercicio 1
from numpy import *
from scipy import linalg

A = array(
    [
        [1, 1],
        [0, 1],
        [0, -1],
        [-1, -1]
    ]
)

b = array(
    [
        [16],
        [8],
        [-8],
        [-32]
    ]
)

Q = array(
    [
        [1 / sqrt(2), 0],
        [0, 1 / sqrt(2)],
        [0, -1 / sqrt(2)],
        [-1 / sqrt(2), 0]
    ]
)
# Out:
# [[-7.07106781e-01 -2.37213427e-17  9.82570185e-18  7.07106781e-01]
#  [-0.00000000e+00 -7.07106781e-01  7.07106781e-01 -3.35470445e-17]
#  [-0.00000000e+00  7.07106781e-01  7.07106781e-01  1.38956408e-17]
#  [ 7.07106781e-01 -2.37213427e-17  9.82570185e-18  7.07106781e-01]]
# [[-1.41421356 -1.41421356]
#  [ 0.         -1.41421356]
#  [ 0.          0.        ]
#  [ 0.          0.        ]]
