# %%
# Computo con el método de Heunn la ecuación de segundo orden habiendola reducido
# utilizando la estimación del K2 con el Euler de 1° orden.
from numpy import *
def heunn(x0, f, t0, tf, n):
    """ Calcula la evolución del sistema o ecuación diferencial empleando como método de aproximación
        el método de Heunn, un método Runge Kutta de segundo orden que emplea aproximación por el área del trapecio.
        :parametro x0: Estado inicial, condiciones iniciales
        :parametro f: Función de carga f(t,x)
        :parametro t0: Tiempo inicial
        :parametro tf: Tiempo final
        :parametro n: Cantidad de puntos
    """
    t = [t0]
    x = [x0]
    for i in range(1, n+1):
        t.append()
# Out:
# [2 1]
# [68.13156206  4.8       ]
# [5.4065781 1.24     ]
# [93.32620937  6.34914292]
# [10.07288857  1.55745715]
# [125.94555658   8.37181743]
# [16.3701664   1.97604802]
# [167.98275106  11.0014003 ]
# [24.76930395  2.52611803]
# [221.93941223  14.40662826]
# [35.86627456  3.24644945]
# [290.95122939  18.80058655]
# [50.41383603  4.18647877]
# [378.94389924  24.45191572]
# [69.361031    5.40907456]
# [490.82661381  31.69877233]
# [93.90236169  6.99401318]
# [632.73200167  40.96620685]
# [125.53896177   9.04232352]
# [812.31351146  52.78777898]

# %%
# Graficamos los resultados y los comparamos con los reales
xreal = 4 * exp(-0.5 * t) + 7 * exp(3 * t) - 9 * exp(2 * t)

# Ploteando
from matplotlib import pyplot

pyplot.plot(t, y, label="Estimación")
pyplot.plot(t, xreal, label="Real")
pyplot.grid()
pyplot.legend()
pyplot.show()
