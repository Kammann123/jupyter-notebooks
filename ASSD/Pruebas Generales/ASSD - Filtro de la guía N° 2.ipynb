# %%
import numpy as np
from matplotlib import pyplot

tetha = 100
w = np.arange(1, 100, 1 / 1000)
h = np.sqrt(4 * np.cos(w) ** 2 - 8 * np.cos(tetha) * np.cos(w) + 4 * np.cos(tetha)**2)

pyplot.semilogx(w, h)
pyplot.show()
